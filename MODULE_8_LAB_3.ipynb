# %% [markdown]
# <a href="https://colab.research.google.com/github/SaiSruthi91/FMML-ASSIGNMENTS/blob/main/MODULE_8_LAB_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-05 08:03:40--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   181MB/s    in 0.4s
#
# 2023-05-05 08:03:45 (181 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 40482   1201.2575v2  For a large multi-hop wireless network, nodes ...    cs
# 40450   1108.2580v2  This paper describes the solution method taken...    cs
# 6226   1609.09481v1  We study fast learning rates when the losses a...  stat
# 37176  1609.05835v1  This provocation paper provides an overview of...    cs
# 5352    1304.3285v4  Inference for latent feature models is inheren...  stat
# ...             ...                                                ...   ...
# 11847  1702.07709v1  Many conventional statistical procedures are e...  stat
# 22041   1404.1238v3  This paper considers the problem of estimating...  stat
# 1324    1411.5908v2  Despite the importance of image representation...    cs
# 3171   1604.02917v2  We present a novel approach for supervised dom...  stat
# 6967   1708.04106v3  Models applied on real time response task, lik...  stat
#
#                                                    title  year  \
# 40482  Joint Approximation of Information and Distrib...  2012
# 40450        Efficient Multicore Collaborative Filtering  2011
# 6226        Fast learning rates with heavy-tailed losses  2016
# 37176  Scope for Machine Learning in Digital Manufact...  2016
# 5352   Scaling the Indian Buffet Process via Submodul...  2013
# ...                                                  ...   ...
# 11847  Computationally Efficient Robust Estimation of...  2017
# 22041  Exact Estimation of Multiple Directed Acyclic ...  2014
# 1324   Understanding image representations by measuri...  2014
# 3171   Gaussian Process Domain Experts for Model Adap...  2016
# 6967   Rocket Launching: A Universal and Efficient Fr...  2017
#
#                                                 keywords
# 40482  [preferable, distributed, localized, schedulin...
# 40450  [describes, lebusishu, identified, challenges,...
# 6226   [necessarily, distribution, introduce, conditi...
# 37176  [provocation, underlying, optimisation, manufa...
# 5352   [inference, inherently, difficult, inference, ...
# ...                                                  ...
# 11847  [conventional, statistical, procedures, extrem...
# 22041  [considers, estimating, structure, development...
# 1324   [importance, representations, histograms, grad...
# 3171   [supervised, adaptation, probabilistic, framew...
# 6967   [prediction, therefore, performing, complexity...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 40482    [preferable, distributed, localized, schedulin...
# 40450    [describes, lebusishu, identified, challenges,...
# 6226     [necessarily, distribution, introduce, conditi...
# 37176    [provocation, underlying, optimisation, manufa...
# 5352     [inference, inherently, difficult, inference, ...
#                                ...
# 2477     [demonstrate, possibility, classifying, struct...
# 22416    [introduce, correlation, multivariate, nonline...
# 22004    [combining, information, different, classifica...
# 31855    [introduces, collaborative, cognitive, seconda...
# 21765    [hierarchies, theoretically, experimented, vis...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8871 words.
# Out of those 4536 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="86885f9f-16d7-4a82-bd1e-7500df29ec9a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("86885f9f-16d7-4a82-bd1e-7500df29ec9a")) {                    Plotly.newPlot(                        "86885f9f-16d7-4a82-bd1e-7500df29ec9a",                        [{"x":["incorporated","interference","localized","neighbors","approaches","convergence","scheduling","populated","characterize","simulation","decisions","individual","approximated","distributed","probability","iterative","implemented","nontrivial","interactions","insufficient","information","variables","distribution","preferable","interactive","characterized","iterations","approximation","algorithm","neighborhood","efficient","supercomputer","prediction","characteristics","multicore","algorithms","computing","collaborative","preliminary","describes","framework","identified","challenges","performance","filtering","regularization","solutions","factorization","assumptions","clustering","integrable","literature","distributions","complement","viewpoints","introduce","arbitrarily","depending","necessarily","condition","theoretical","conditions","satisfies","bernsteins","hypothesis","quantization","practical","initially","integration","manufacturing","computerised","functions","concurrent","processes","optimisation","integrated","objective","opportunity","discusses","collection","transforming","describing","production","incorporating","underlying","application","inference","maximization","inherently","difficult","formulation","submodular","nonnegative","corresponds","expectation","maximized","approximate","exponentially","currently","indicated","screening","digitizing","developed","outperformed","interpretable","cognitive","inexpensive","substantially","techniques","automated","methodology","considerable","resulting","benchmark","precision","interpretability","clinicians","analogies","dimensional","generalization","estimates","visualized","structured","generative","histograms","histogram","estimation","dimensions","significant","likelihood","significantly","observations","probabilistic","parameters","irregularly","important","demonstrate","incorporates","nonparametric","incorporate","analyzing","experimental","sensitive","mechanisms","extensive","parameter","contributions","knowledge","identifying","complexity","optimization","different","improvement","sinusoidal","challenge","estimating","understanding","experiments","disciplines","architectural","ingredients","architecture","principles","operation","perspectives","functional","effectiveness","proposing","efficiency","particular","manifested","proximity","accordingly","embeddings","performed","leverages","consensus","representation","attribute","properties","nonetheless","effective","structure","following","attributes","perturbation","fundamental","attributed","corroborate","embedding","associated","necessitates","importance","environment","classification","correlated","synthetic","naturally","incomplete","correlations"],"y":[29,7,16,23,446,120,22,4,49,86,65,104,23,111,184,72,102,6,77,14,668,134,239,9,40,32,28,130,830,23,400,2,226,96,2,605,132,28,61,73,545,36,116,901,72,85,167,36,69,135,0,120,119,19,15,334,16,46,14,58,159,120,13,0,53,25,136,18,43,6,2,201,9,90,14,62,154,12,21,71,16,41,19,69,131,259,186,26,18,138,84,14,7,26,23,5,99,22,63,7,6,1,195,21,23,38,5,32,392,106,69,39,180,224,82,19,2,2,180,110,73,1,104,98,9,30,208,44,249,51,250,76,177,219,1,307,541,28,12,48,59,366,71,45,154,125,57,344,83,242,310,720,141,2,147,60,162,596,13,11,8,248,35,42,27,44,210,23,164,251,2,15,20,80,106,34,14,353,41,238,3,270,326,90,72,22,91,11,6,105,104,4,85,132,524,32,125,56,40,41],"type":"bar"},{"x":["incorporated","interference","localized","neighbors","approaches","c ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4536,), (4536, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8025

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Efficient</span> <span style=''>Sample</span> <span style=''>Reuse</span> <span style=''>in</span> <span style=''>Policy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Gradients</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Parameter</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Exploration</span> <br/><br/><span style=''>The</span> <span style=''>policy</span> <span style=''>gradient</span> <span style=''>approach</span> <span style=''>is</span> <span style=''>a</span> <span style=''>flexible</span> <span style=''>and</span> <span style=''>powerful</span> <span style='background-color:rgba(0, 255, 0, 0.30061349693251527);'>reinforcement</span> <span style=''>learning</span> <span style=''>method</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particularly</span> <span style=''>for</span> <span style=''>problems</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>continuous</span> <span style=''>actions</span> <span style=''>such</span> <span style=''>as</span> <span style=''>robot</span> <span style=''>control</span> <span style=''>A</span> <span style=''>common</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>challenge</span> <span style=''>in</span> <span style=''>this</span> <span style=''>scenario</span> <span style=''>is</span> <span style=''>how</span> <span style=''>to</span> <span style=''>reduce</span> <span style=''>the</span> <span style=''>variance</span> <span style=''>of</span> <span style=''>policy</span> <span style=''>gradient</span> <span style='background-color:rgba(255, 0, 0, 0.30143540669856456);'>estimates</span> <span style=''>for</span> <span style=''>reliable</span> <span style=''>policy</span> <span style=''>updates</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>combine</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>following</span> <span style=''>three</span> <span style=''>ideas</span> <span style=''>and</span> <span style=''>give</span> <span style=''>a</span> <span style=''>highly</span> <span style='background-color:rgba(0, 255, 0, 0.32029339853300726);'>effective</span> <span style=''>policy</span> <span style=''>gradient</span> <span style=''>method</span> <span style=''>(a)</span> <span style=''>the</span> <span style=''>policy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>gradients</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameter</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exploration</span> <span style=''>which</span> <span style=''>is</span> <span style=''>a</span> <span style=''>recently</span> <span style=''>proposed</span> <span style=''>policy</span> <span style=''>search</span> <span style=''>method</span> <span style=''>with</span> <span style=''>low</span> <span style=''>variance</span> <span style=''>of</span> <span style=''>gradient</span> <span style='background-color:rgba(255, 0, 0, 0.30143540669856456);'>estimates</span> <span style=''>(b)</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>importance</span> <span style=''>sampling</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>technique</span> <span style=''>which</span> <span style=''>allows</span> <span style=''>us</span> <span style=''>to</span> <span style=''>reuse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>previously</span> <span style=''>gathered</span> <span style=''>data</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consistent</span> <span style=''>way</span> <span style=''>and</span> <span style=''>(c)</span> <span style=''>an</span> <span style=''>optimal</span> <span s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Supervised</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style=''>remark</span> <span style=''>and</span> <span style=''>some</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>comparisons</span> <br/><br/><span style=''>The</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>(or</span> <span style=''>discrimination)</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functional</span> <span style=''>data</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>considered</span> <span style=''>with</span> <span style=''>a</span> <span style=''>special</span> <span style=''>interest</span> <span style=''>on</span> <span style=''>the</span> <span style=''>popular</span> <span style=''>k</span> <span style=''>nearest</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>neighbors</span> <span style=''>(k</span> <span style=''>NN)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>First</span> <span style=''>relying</span> <span style=''>on</span> <span style=''>a</span> <span style=''>recent</span> <span style=''>result</span> <span style=''>by</span> <span style=''>Cerou</span> <span style=''>and</span> <span style=''>Guyader</span> <span style=''>(2006)</span> <span style=''>we</span> <span style=''>prove</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consistency</span> <span style=''>of</span> <span style=''>the</span> <span style=''>k</span> <span style=''>NN</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functional</span> <span style=''>data</span> <span style=''>whose</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>belongs</span> <span style=''>to</span> <span style=''>a</span> <span style=''>broad</span> <span style=''>family</span> <span style=''>of</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>triangular</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariance</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>Second</span> <span style=''>on</span> <span style=''>a</span> <span style=''>more</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>practical</span> <span style=''>side</span> <span style=''>we</span> <span style=''>check</span> <span style=''>the</span> <span style=''>behavior</span> <span style=''>of</span> <span style=''>the</span> <span style=''>k</span> <span style=''>NN</span> <span style=''>method</span> <span style=''>when</span> <span style=''>compared</span> <span style=''>with</span> <span style=''>a</span> <span style=''>few</span> <span style=''>other</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifiers</span> <span style=''>This</span> <span style=''>is</span> <span style=''>carried</span> <span style=''>out</span> <span style=''>through</span> <span style=''>a</span> <span style=''>small</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simulation</span> <span style=''>study</span> <span style=''>and</span> <span style=''>the</span> <span style=''>analysis</span> <span style=''>of</span> <span style=''>several</span> <span style=''>real</span> <span style='backgro ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Beyond</span> <span style=''>Gauss</span> <span style=''>Image</span> <span style=''>Set</span> <span style=''>Matching</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Riemannian</span> <span style=''>Manifold</span> <span style=''>of</span> <span style=''>PDFs</span> <br/><br/><span style=''>State</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>image</span> <span style=''>set</span> <span style=''>matching</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>techniques</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>typically</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implicitly</span> <span style=''>model</span> <span style=''>each</span> <span style=''>image</span> <span style=''>set</span> <span style=''>with</span> <span style=''>a</span> <span style=''>Gaussian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>Here</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>to</span> <span style=''>go</span> <span style=''>beyond</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.41954022988505746);'>representations</span> <span style=''>and</span> <span style=''>model</span> <span style=''>image</span> <span style=''>sets</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>(PDFs)</span> <span style=''>using</span> <span style=''>kernel</span> <span style=''>density</span> <span style='background-color:rgba(255, 0, 0, 0.8072289156626506);'>estimators</span> <span style=''>To</span> <span style=''>compare</span> <span style=''>and</span> <span style=''>match</span> <span style=''>image</span> <span style=''>sets</span> <span style=''>we</span> <span style=''>exploit</span> <span style=''>Csiszar</span> <span style=''>f</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>divergences</span> <span style=''>which</span> <span style=''>bear</span> <span style=''>strong</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>connections</span> <span style=''>to</span> <span style=''>the</span> <span style=''>geodesic</span> <span style=''>distance</span> <span style=''>defined</span> <span style=''>on</span> <span style=''>the</span> <span style=''>space</span> <span style=''>of</span> <span style=''>PDFs</span> <span style=''>ie</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>statistical</span> <span style=''>manifold</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Furthermore</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>valid</span> <span style=''>positive</span> <span style=''>definite</span> <span style=''>kernels</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>statistical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>manifolds</span> <span style=''>which</span> <span style=''>let</span> <span style=''>us</span> <span style=''>make</span> <span style=''>use</span> <span style=''>of</span> <span style=''>more</span> <span style=''>powerful</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>schemes</span> <span style=''>to</span> <span style=''>match</span> <span style=''>image</span> <span style=''>sets</span> <span style=''>Finally</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>supervised</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dimensionality</span> <span style=' ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Subset</span> <span style=''>Labeled</span> <span style=''>LDA</span> <span style=''>for</span> <span style=''>Large</span> <span style=''>Scale</span> <span style=''>Multi</span> <span style=''>Label</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Classification</span> <br/><br/><span style=''>Labeled</span> <span style=''>Latent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dirichlet</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Allocation</span> <span style=''>(LLDA)</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extension</span> <span style=''>of</span> <span style=''>the</span> <span style=''>standard</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unsupervised</span> <span style=''>Latent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dirichlet</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Allocation</span> <span style=''>(LDA)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>to</span> <span style=''>address</span> <span style=''>multi</span> <span style=''>label</span> <span style=''>learning</span> <span style=''>tasks</span> <span style=''>Previous</span> <span style=''>work</span> <span style=''>has</span> <span style=''>shown</span> <span style=''>it</span> <span style=''>to</span> <span style=''>perform</span> <span style=''>in</span> <span style=''>par</span> <span style=''>with</span> <span style=''>other</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>multi</span> <span style=''>label</span> <span style=''>methods</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Nonetheless</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>increasing</span> <span style=''>label</span> <span style=''>sets</span> <span style=''>sizes</span> <span style=''>LLDA</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>encounters</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>scalability</span> <span style=''>issues</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>Subset</span> <span style=''>LLDA</span> <span style=''>a</span> <span style=''>simple</span> <span style=''>variant</span> <span style=''>of</span> <span style=''>the</span> <span style=''>standard</span> <span style=''>LLDA</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>that</span> <span style=''>not</span> <span style=''>only</span> <span style=''>can</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effectively</span> <span style=''>scale</span> <span style=''>up</span> <span style=''>to</span> <span style=''>problems</span> <span style=''>with</span> <span style=''>hundreds</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>thousands</span> <span style=''>of</span> <span style=''>labels</span> <span style=''>but</span> <span style=''>also</span> <span style=''>improves</span> <span style=''>over</span> <span style=''>the</span> <span style=''>LLDA</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>We</span> <span style=''>conduct</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extensive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experiments</span> <span style=''>on</span> <span style=''>eight</span> <span style=''>data</span> <span style=''>sets</span> <span style=''>with</span> <span style=''>label</span> <span style=''>sets</span> <span style=''>sizes</span> <span style=''>ranging</span> <span style=''>from</span> <span style=''>hundreds</span> <span style=''>to</span> <span style=''>hundreds</sp ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.09900990099009901)
# 	experimental (0.12942008486562942)
# 	representation (0.12482319660537482)
# 	architecture (0.0876944837340877)
# 	knowledge (0.12164073550212164)
# 	segmentation (0.06753889674681754)
# 	different (0.2545968882602546)
# 	detection (0.12234794908062235)
# 	recognition (0.12623762376237624)
# 	convolutional (0.13437057991513437)
#
# Some Statistics words are:
# 	stochastic (0.13691683569979715)
# 	algorithm (0.38488843813387424)
# 	statistical (0.15415821501014199)
# 	variables (0.14198782961460446)
# 	estimation (0.17342799188640973)
# 	distribution (0.18864097363083165)
# 	theoretical (0.16176470588235295)
# 	dimensional (0.19523326572008112)
# 	inference (0.19929006085192696)
# 	regression (0.17748478701825557)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="5fddd376-e33f-4599-9d5c-60976a21ed77" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5fddd376-e33f-4599-9d5c-60976a21ed77")) {                    Plotly.newPlot(                        "5fddd376-e33f-4599-9d5c-60976a21ed77",                        [{"x":["incorporated","interference","localized","neighbors","approaches","convergence","scheduling","populated","characterize","simulation","decisions","individual","approximated","distributed","probability","iterative","implemented","nontrivial","interactions","insufficient","information","variables","distribution","preferable","interactive","characterized","iterations","approximation","algorithm","neighborhood","efficient","supercomputer","prediction","characteristics","multicore","algorithms","computing","collaborative","preliminary","describes","framework","identified","challenges","performance","filtering","regularization","solutions","factorization","assumptions","clustering","integrable","literature","distributions","complement","viewpoints","introduce","arbitrarily","depending","necessarily","condition","theoretical","conditions","satisfies","bernsteins","hypothesis","quantization","practical","initially","integration","manufacturing","computerised","functions","concurrent","processes","optimisation","integrated","objective","opportunity","discusses","collection","transforming","describing","production","incorporating","underlying","application","inference","maximization","inherently","difficult","formulation","submodular","nonnegative","corresponds","expectation","maximized","approximate","exponentially","currently","indicated","screening","digitizing","developed","outperformed","interpretable","cognitive","inexpensive","substantially","techniques","automated","methodology","considerable","resulting","benchmark","precision","interpretability","clinicians","analogies","dimensional","generalization","estimates","visualized","structured","generative","histograms","histogram","estimation","dimensions","significant","likelihood","significantly","observations","probabilistic","parameters","irregularly","important","demonstrate","incorporates","nonparametric","incorporate","analyzing","experimental","sensitive","mechanisms","extensive","parameter","contributions","knowledge","identifying","complexity","optimization","different","improvement","sinusoidal","challenge","estimating","understanding","experiments","disciplines","architectural","ingredients","architecture","principles","operation","perspectives","functional","effectiveness","proposing","efficiency","particular","manifested","proximity","accordingly","embeddings","performed","leverages","consensus","representation","attribute","properties","nonetheless","effective","structure","following","attributes","perturbation","fundamental","attributed","corroborate","embedding","associated","necessitates","importance","environment","classification","correlated","synthetic","naturally","incomplete","correlations","uncertainty","intelligence","artificial","proceedings","conference","unlabeled","estimators","cardinality","supervised","completely","formulate","explicitly","regression","comparisons","statistical","recognition","expressions","relations","architectures","correspond","correlates","augmentation","perturbations","parameterized","predictive","thousands","sensitivity","connected","typically","establish","empirical","counterparts","robustness","linearities","observation","investigate","exploration","classical","generalize","optimizers","gradients","reparameterization","invertible","transformations","technique","variational","applications","generalized","transformed","approximations","corollaries","representations","extending","preserv ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	integrable
# 	bernsteins
# 	linearities
# 	clusterings
# 	sparsistency
# 	stagewise
# 	rewritten
# 	repulsive
# 	infinitesimal
# 	jackknife
# 	operationally
# 	multipartite
# 	varepsilon
# 	transplantation
# 	forecasts
# 	hypernetwork
# 	hypernetworks
# 	penalizes
# 	confirming
# 	cubically
# Some words which never appear in Statistics papers:
# 	populated
# 	supercomputer
# 	computerised
# 	necessitates
# 	proactive
# 	representatives
# 	strategically
# 	reordering
# 	communicative
# 	adjoining
# 	discourse
# 	grammatical
# 	pragmatics
# 	rewriting
# 	fulfilling
# 	syntactical
# 	termination
# 	substitutions
# 	syntactic
# 	positivenegative

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0472940029254025e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7641666666666667
